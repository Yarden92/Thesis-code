# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np

from src.split_step_fourier import SplitStepFourier
from src.visualizer import Visualizer

# %%
Po = .00064
Ao = np.sqrt(Po)
C = -2
to = 125e-12

t_vec = np.arange(-4096e-12, 4095e-12, 1e-12)
x = Ao * np.exp(-((1 + 1j * (-C)) / 2.0) * (t_vec / to) ** 2)

ssf = SplitStepFourier(
    b2=-20e-27,
    gamma=0.003,
    t0=125e-12,
    z_n=1.51,
    dt=1e-12,
    h=1000)

y = ssf.start_minimal(x)
# Out:
# SSF params: N = 1179, P_0 = 0.00042666666666666667

# %%
ssf.plot_input(range(len(x)), x)

# %%
Visualizer.twin_zoom_plot('real example(x(t))',np.real(x),range(4000,4200))

# %%
Visualizer.print_signal_specs(x, t_vec)
# Out:
# signal power = 3.77e-01
# signal bw = [-3.79e-10:3.79e-10]

# %%
ssf.plot_output(t_vec, y)

# %%
Visualizer.twin_zoom_plot('real example(y(t))',np.real(y),range(4000,4200))

# %%
# initial setup for any notebook

# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("/home/yarcoh/projects/thesis-code4") # go to parent dir

# %%
from apps.optics.noise_searcher import NoiseSearcher


ns = NoiseSearcher()

# %%
BERs, mus, Ds = ns.load_ber_map('../../data/ber_maps/2023.06.10-22.38.52')

# %%
ns.print_ber_map(BERs, mus, Ds)
# Out:
# +--------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+
# | mu \ D | 1.00e-17 | 1.83e-17 | 3.36e-17 | 6.16e-17 | 1.13e-16 | 2.07e-16 | 3.79e-16 | 6.95e-16 | 1.27e-15 | 2.34e-15 | 4.28e-15 | 7.85e-15 | 1.44e-14 | 2.64e-14 | 4.83e-14 | 8.86e-14 | 1.62e-13 | 2.98e-13 | 5.46e-13 | 1.00e-12 |
# +--------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+
# | 0.200  | 0.00e+00 | 0.00e+00 | 1.95e-04 | 0.00e+00 | 0.00e+00 | 0.00e+00 | 0.00e+00 | 1.95e-04 | 9.77e-04 | 1.56e-03 | 5.31e-02 | 3.94e-01 | 9.69e-01 | 1.00e+00 | 1.00e+00 | 1.00e+00 | 1.00e+00 | 1.00e+00 | 1.00e+00 | 1.00e+00 |
# ...

# %%
import numpy as np
np.min(BERs)
# Out:
# 0.0

# %%
ns.plot_ber_map(BERs, mus, Ds)
# Out:
# /home/yarcoh/projects/thesis-code4/apps/optics/noise_searcher.py:108: RuntimeWarning: divide by zero encountered in log10
#   k = np.floor(np.log10(np.min(BERs)))
